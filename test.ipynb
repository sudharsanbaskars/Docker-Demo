# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
import numpy as np
import pandas as pd
from sklearn import decomposition
import matplotlib.pyplot as plt

# %%
train_path = "Prediction_FileFromDB/InputFile.csv"

# %%
train_df = pd.read_csv(train_path)

# %%
train_df.shape
# Out:
# (100, 591)

# %%
train_df.head()
# Out:
#    Wafer  Sensor - 1  Sensor - 2  Sensor - 3  Sensor - 4  Sensor - 5  \
# 0   1201     3045.98     2544.85   2253.3444   1873.8678      1.1691
# 1   1202     3151.98     2563.75   2175.2556   1022.1660      1.2833
# 2   1203     3071.18     2489.86   2195.3000   1151.8233      0.9220
# 3   1204     2958.46     2523.78   2171.8556   1156.6018      1.4025
# 4   1205     3196.21     2413.39   2255.5222   1763.0739      1.2226
#
#    Sensor - 6  Sensor - 7  Sensor - 8  Sensor - 9  ...  Sensor - 581  \
# 0       100.0     94.9722      0.1210      1.4752  ...           NaN
# 1       100.0    100.6222      0.1250      1.4536  ...           NaN
# 2       100.0    103.5467      0.1232      1.4826  ...           NaN
# 3       100.0    100.1367      0.1243      1.4645  ...           NaN
# 4       100.0    101.5878      0.1200      1.4845  ...        0.0057
#
#    Sensor - 582  Sensor - 583  Sensor - 584  Sensor - 585  Sensor - 586  \
# ...

# %%
def impute(data):
    imputer=KNNImputer(n_neighbors=3, weights='uniform',missing_values=np.nan)
    new_array=imputer.fit_transform(data) # impute the missing values
    # convert the nd-array returned in the step above to a Dataframe
    new_data=pd.DataFrame(data=new_array, columns=data.columns)
    return new_data

# %%
train_df = impute(train_df)

# %%
train_df = train_df.drop("Wafer", axis="columns")

# %%
#X = train_df.drop("Output", axis="columns")
#y = train_df["Output"]

# %%
standardized_data = StandardScaler().fit_transform(train_df)
print(standardized_data.shape)
# Out:
# (100, 590)

# %%
pca = decomposition.PCA(n_components=163)
pca_data = pca.fit_transform(standardized_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2e448fb04375> in <module>
#       1 pca = decomposition.PCA(n_components=163)
# ----> 2 pca_data = pca.fit_transform(standardized_data)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\decomposition\_pca.py in fit_transform(self, X, y)
#     367         C-ordered array, use 'np.ascontiguousarray'.
#     368         """
# --> 369         U, S, V = self._fit(X)
#     370         U = U[:, :self.n_components_]
#     371
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     414         # Call different fits for either full or truncated SVD
#     415         if self._fit_svd_solver == 'full':
# --> 416             return self._fit_full(X, n_components)
#     417         elif self._fit_svd_solver in ['arpack', 'randomized']:
# ...

# %%
pca_data.shape
# Out:
# (6696, 163)

# %%
pca_df = pd.DataFrame(pca_data)

# %%
pca_df
# Out:
#             0          1         2         3         4         5         6    \
# 0      5.189779  -2.526438  7.261553 -0.255659 -4.722391 -2.676904  6.686961
# 1      0.894490  -6.270891 -2.557976 -1.899585 -0.213330  1.634101  0.220302
# 2      0.084783  -2.963310 -0.869594  0.630303 -1.543923 -0.979699  0.616491
# 3      1.415289  -4.635240 -0.927182 -0.140596 -1.873369 -2.512656  0.079036
# 4     -0.668600  -0.687600  3.841711  1.942508 -2.264071 -4.961531 -0.438886
# ...         ...        ...       ...       ...       ...       ...       ...
# 6691   1.347509  -6.782388  0.018732 -1.293090  2.904536 -0.300537  0.970849
# 6692   0.141703  -6.113462 -1.602204 -0.436855  1.409121 -1.038587  1.522141
# 6693  16.169613  -0.868282  2.122418  1.665573  1.184510 -3.274623 -1.167089
# 6694   0.159206  -8.915187 -0.293667  0.163459 -3.499323 -1.353166  3.212743
# 6695   1.741821 -11.347451 -4.266862 -2.895037 -1.781129  6.738181 -2.194939
#
# ...

# %%
pca.n_components_
# Out:
# 163

# %%
import json

# %%
dt = {"n_components": 12}
with open("js.json", "w") as f:
    dic = json.dump(dt, f)
    f.close()
# dic["n_components"]
